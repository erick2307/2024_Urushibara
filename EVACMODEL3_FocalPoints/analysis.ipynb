# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# We need to see if reinforcing the best policy is better than just keep iterating with a suboptimal policy.

# %%
df_nr = pd.read_csv('./data_noreinforce/StatesMatrices/survivorsPerSim.csv', names=['run','survivors'])
dfs_nr = pd.read_csv('./data_noreinforce/shortesPath_TimeVSEvacuated.csv', names=['time','survivors'])

df_wr = pd.read_csv('./data/StatesMatrices/survivorsPerSim.csv', names=['run','survivors'])
dfs_wr = pd.read_csv('./data/shortesPath_TimeVSEvacuated.csv', names=['time','survivors'])

# %%
df_nr['survivors'].max(), df_wr['survivors'].max()
# Out:
# (26290, 26065)

# %%
df_nr['survivors'].idxmax(), df_wr['survivors'].idxmax()
# Out:
# (88, 66)

# %%
df_nr['survivors'].tail(), df_wr['survivors'].tail()
# Out:
# (96     25557
#  97     25748
#  98     25909
#  99     26023
#  100    25937
#  Name: survivors, dtype: int64,
#  96     25891
#  97     25798
#  98     25922
#  99     25674
#  100    25826
#  Name: survivors, dtype: int64)

# %%
ax = df_wr['survivors'].expanding().mean().plot(label='wr')
df_nr['survivors'].expanding().mean().plot(ax=ax,label='nr')
plt.ylim(22500,27000)
plt.legend()

# %%
dfs_nr['survivors'].max(), dfs_wr['survivors'].max()
# Out:
# (26869.0, 26903.0)

# %%
df = pd.read_csv('./data/StatesMatrices/survivorsPerSim.csv', names=['run','survivors'])
dfs = pd.read_csv('./data/shortesPath_TimeVSEvacuated.csv', names=['time','survivors'])
dfs.head()
# Out:
#    time  survivors
# 0   6.0      775.0
# 1   7.0      775.0
# 2   8.0      775.0
# 3   9.0      775.0
# 4  10.0      775.0

# %%
mu = df['survivors'].expanding().mean()
sd = df['survivors'].expanding().std()
cv = sd / mu
cv.plot()
# Out:
# <Axes: >

# %%
# We need an output of 'SARSA_TimesVsEvacuated.csv' to plot here and compare
dfs['survivors'].plot()
# Out:
# <Axes: >

# %%
import numpy as np 

survivorsPerSim = [[1,10],[2,14],[3,56],[4,34],[5,12]]

# %%
dff = pd.DataFrame(survivorsPerSim, columns=['numSim','survivors'])
id = dff['survivors'].idxmax()
dff['numSim'][id]
# Out:
# 3
